# %% [markdown]
# **STREESSLEVEL PREDICTION**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"D:\Downloads\Sleep_health_and_lifestyle_dataset.csv")
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
data.tail(3)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 371          68         7000    Sleep Apnea
# 372          68         7000    Sleep Apnea
# 373          68         7000    Sleep Apnea

# %%
data.size
# Out:
# 4862

# %%
data.shape
# Out:
# (374, 13)

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
#barplot
plt.figure(figsize=(15,7))
plt.bar(data['Age'],data['Blood Pressure'],color="purple")
plt.title("bp of person according to the age(normal less than 120/80mmHg)")
plt.xlabel("age")
plt.ylabel("blood pressure")
# plt.legend()
plt.show()

# %%
# scatter plot
plt.figure(figsize=(12,8))
sns.scatterplot(x="Heart Rate",y="Physical Activity Level",data=data,hue="Gender",palette="rainbow")
# Out:
# <Axes: xlabel='Heart Rate', ylabel='Physical Activity Level'>

# %%
#strip plot
plt.figure(figsize=(15,7))
sns.stripplot(x="Age",y="Stress Level",data=data,hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Stress Level'>

# %%
#count plot
sns.countplot(y='BMI Category',data=data,color="purple")
# Out:
# <Axes: xlabel='count', ylabel='BMI Category'>

# %%
from sklearn.preprocessing import LabelEncoder
ob1=LabelEncoder()
ob2=LabelEncoder()
ob3=LabelEncoder()
ob4=LabelEncoder()
ob5=LabelEncoder()
data['Gender']=ob1.fit_transform(data['Gender'])
data['Occupation']=ob2.fit_transform(data['Occupation'])
data['BMI Category']=ob3.fit_transform(data['BMI Category'])
data['Blood Pressure']=ob4.fit_transform(data['Blood Pressure'])
data['Sleep Disorder']=ob5.fit_transform(data['Sleep Disorder'])
data.head()
# Out:
#     Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3           4       1   28           5             5.9                 4
# 4           5       1   28           5             5.9                 4
# 5           6       1   28           8             5.9                 4
# 6           7       1   29           9             6.3                 6
# 16         17       0   29           4             6.5                 5
#
#     Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 3                        30             8             2              11
# 4                        30             8             2              11
# 5                        30             8             2              11
# 6                        40             7             2              11
# 16                       40             7             1               7
#
#     Heart Rate  Daily Steps  Sleep Disorder
# 3           85         3000               1
# ...

# %%
data.corr()
# Out:
#                          Person ID    Gender       Age  Occupation  \
# Person ID                 1.000000 -0.482298  0.981739   -0.213495
# Gender                   -0.482298  1.000000 -0.494659   -0.043818
# Age                       0.981739 -0.494659  1.000000   -0.282447
# Occupation               -0.213495 -0.043818 -0.282447    1.000000
# Sleep Duration            0.465877 -0.151298  0.550193   -0.271825
# Quality of Sleep          0.661836 -0.320744  0.710221   -0.240619
# Physical Activity Level   0.573090 -0.369800  0.604725   -0.462270
# Stress Level             -0.417244  0.296294 -0.452398   -0.112576
# BMI Category              0.532017 -0.283469  0.485724    0.347703
# Blood Pressure            0.559666 -0.616181  0.587323   -0.046855
# Heart Rate               -0.409011  0.317304 -0.373515   -0.367883
# Daily Steps               0.447782 -0.391015  0.434277   -0.224843
# Sleep Disorder            0.311089 -0.414514  0.395798   -0.351253
#
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.select_dtypes(['number']).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.drop(['Person ID'],axis=1,inplace=True)
data
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3         1   28           5             5.9                 4
# 4         1   28           5             5.9                 4
# 5         1   28           8             5.9                 4
# 6         1   29           9             6.3                 6
# 16        0   29           4             6.5                 5
# ..      ...  ...         ...             ...               ...
# 369       0   59           4             8.1                 9
# 370       0   59           4             8.0                 9
# 371       0   59           4             8.1                 9
# 372       0   59           4             8.1                 9
# 373       0   59           4             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 3                         30             8             2              11
# ...

# %%
x=data.drop(['Stress Level'],axis=1)
y=data['Stress Level']
x
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3         1   28           5             5.9                 4
# 4         1   28           5             5.9                 4
# 5         1   28           8             5.9                 4
# 6         1   29           9             6.3                 6
# 16        0   29           4             6.5                 5
# ..      ...  ...         ...             ...               ...
# 369       0   59           4             8.1                 9
# 370       0   59           4             8.0                 9
# 371       0   59           4             8.1                 9
# 372       0   59           4             8.1                 9
# 373       0   59           4             8.1                 9
#
#      Physical Activity Level  BMI Category  Blood Pressure  Heart Rate  \
# 3                         30             2              11          85
# ...

# %%
from sklearn.feature_selection import SelectKBest
bestfeature=SelectKBest()
fit=bestfeature.fit(x,y)
fit
# Out:
# SelectKBest()

# %%
dfscore=pd.DataFrame(fit.scores_,columns=['score'])
dfcol=pd.DataFrame(x.columns,columns=['feature'])
fs=pd.concat([dfcol,dfscore],axis=1)
fs
# Out:
#                     feature       score
# 0                    Gender   31.867639
# 1                       Age   31.955670
# 2                Occupation   25.742659
# 3            Sleep Duration  340.880915
# 4          Quality of Sleep  163.937696
# 5   Physical Activity Level   40.135682
# 6              BMI Category   15.042353
# 7            Blood Pressure   52.713684
# 8                Heart Rate   32.440130
# 9               Daily Steps   27.072652
# 10           Sleep Disorder   48.794595

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)
xtest
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 258       0   45           9             6.6                 7
# 361       0   59           4             8.2                 9
# 191       1   43           6             6.4                 6
# 189       1   43           6             6.5                 6
# 306       0   52           0             6.5                 7
# 235       1   44           6             6.3                 6
# 274       0   49           4             6.2                 6
# 366       0   59           4             8.1                 9
# 372       0   59           4             8.1                 9
# 243       0   44           9             6.5                 7
# 202       1   43           2             7.8                 8
# 355       0   58           4             8.0                 9
# 255       0   45           9             6.5                 7
# 252       0   45           9             6.5                 7
# ...

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()
model1.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
print(model1.score(xtest,ytest))
print(model1.score(xtrain,ytrain))
# Out:
# 0.8297872340425532
# 0.9074074074074074

# %%
y_pred1=model1.predict(xtest)
y_pred1
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 5, 4, 8, 8, 3, 8, 7,
#        8, 7, 7, 3, 3, 4, 3, 3, 3, 3, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 7, 5,
#        4, 8, 7], dtype=int64)

# %%
model1.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([7], dtype=int64)

# %% [markdown]
# **DECISIONTREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
print(model2.score(xtest,ytest))
print(model2.score(xtrain,ytrain))
# Out:
# 0.8723404255319149
# 1.0

# %%
y_pred2=model2.predict(xtest)
y_pred2
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 5, 4, 8, 8, 3, 5, 8,
#        5, 7, 7, 3, 4, 4, 4, 4, 4, 4, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 6, 5,
#        4, 8, 8], dtype=int64)

# %%
model2.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([8], dtype=int64)

# %% [markdown]
# **KNN CLASSIFIER**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
xtrain1=scaler.fit_transform(xtrain)

# %%
xtest1=scaler.transform(xtest)

# %%
model3=KNeighborsClassifier(n_neighbors=5)
model3.fit(xtrain1,ytrain)
# Out:
# KNeighborsClassifier()

# %%
print(model3.score(xtest1,ytest))
print(model3.score(xtrain1,ytrain))
# Out:
# 0.7872340425531915
# 0.9351851851851852

# %%
y_pred3=model3.predict(xtest1)
y_pred3
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 7, 4, 8, 8, 3, 5, 7,
#        5, 7, 7, 3, 5, 4, 7, 7, 3, 5, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 5, 5,
#        4, 8, 7], dtype=int64)

# %%
model3.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([8], dtype=int64)

# %% [markdown]
# **RANDOMFOREST CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model4=RandomForestClassifier(n_estimators=100)
model4.fit(xtrain1,ytrain)
# Out:
# RandomForestClassifier()

# %%
print(model4.score(xtest1,ytest))
print(model4.score(xtrain1,ytrain))
# Out:
# 0.9361702127659575
# 1.0

# %%
y_pred4=model4.predict(xtest1)
y_pred4
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 5, 4, 8, 8, 3, 5, 8,
#        5, 7, 7, 3, 4, 4, 5, 5, 4, 4, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 3, 5,
#        4, 8, 8], dtype=int64)

# %%
model4.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([3], dtype=int64)

# %% [markdown]
# **ADABOOST CLASSIFIER**

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model5=AdaBoostClassifier(n_estimators=50,learning_rate=0.3,random_state=1)
model5.fit(xtrain1,ytrain)
# Out:
# AdaBoostClassifier(learning_rate=0.3, random_state=1)

# %%
print(model5.score(xtest1,ytest))
print(model5.score(xtrain1,ytrain))
# Out:
# 0.8085106382978723
# 0.9537037037037037

# %%
y_pred5=model5.predict(xtest1)
y_pred5
# Out:
# array([4, 3, 7, 7, 4, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 7, 4, 8, 8, 3, 5, 8,
#        5, 7, 7, 3, 7, 4, 7, 7, 4, 7, 4, 4, 8, 4, 4, 4, 3, 4, 7, 7, 7, 5,
#        4, 8, 8], dtype=int64)

# %%
model5.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([8], dtype=int64)

# %% [markdown]
# **GRADIENTBOOST CLASSIFIER**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model6=GradientBoostingClassifier(n_estimators=250,random_state=1)
model6.fit(xtrain1,ytrain)
# Out:
# GradientBoostingClassifier(n_estimators=250, random_state=1)

# %%
print(model6.score(xtest1,ytest))
print(model6.score(xtrain1,ytrain))
# Out:
# 0.8723404255319149
# 1.0

# %%
y_pred6=model6.predict(xtest1)
y_pred6
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 5, 4, 8, 8, 3, 5, 7,
#        5, 7, 7, 3, 4, 4, 5, 5, 4, 4, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 6, 5,
#        4, 8, 7], dtype=int64)

# %%
model6.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([3], dtype=int64)

# %% [markdown]
# **XGBOOST CLASSIFIER**

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
model7=XGBClassifier(n_estimators=250,random_state=1)
ytrain1=ytrain-3
model7.fit(xtrain1,ytrain1)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=250, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
print(model7.score(xtest1,ytest))
print(model7.score(xtrain1,ytrain1))
# Out:
# 0.0
# 1.0

# %%
y_pred7=model7.predict(xtest1)
y_pred7
# Out:
# array([1, 0, 4, 4, 4, 4, 5, 0, 0, 1, 2, 0, 1, 1, 4, 2, 1, 5, 5, 0, 2, 4,
#        2, 4, 4, 0, 1, 1, 2, 2, 1, 1, 4, 1, 5, 1, 1, 1, 0, 1, 4, 4, 1, 2,
#        1, 5, 4], dtype=int64)

# %%
model7.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# **SVC**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
model=SVC()

# %%
xtrain2=np.asarray(xtrain1)
ytrain=np.asarray(ytrain)

# %%
parameters={'kernel':['linear','poly','rbf','sigmoid'],
            'C':[1,5,10,20]
           }

# %%
GV=GridSearchCV(model,parameters,cv=5)

# %%
GV.fit(xtrain2,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
GV.best_params_
# Out:
# {'C': 20, 'kernel': 'rbf'}

# %%
model8=SVC(C=20,kernel='rbf')

# %%
model8.fit(xtrain2,ytrain)
# Out:
# SVC(C=20)

# %%
print(model8.score(xtest1,ytest))
print(model8.score(xtrain2,ytrain))
# Out:
# 0.8723404255319149
# 1.0

# %%
y_pred8=model8.predict(xtest1)
y_pred8
# Out:
# array([4, 3, 7, 7, 7, 7, 8, 3, 3, 4, 5, 3, 4, 4, 7, 5, 4, 8, 8, 3, 5, 7,
#        5, 7, 7, 3, 5, 4, 5, 5, 4, 5, 7, 4, 8, 4, 4, 4, 3, 4, 7, 7, 4, 5,
#        4, 8, 7], dtype=int64)

# %%
model8.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([8], dtype=int64)

# %%
a={'test_acc':[0.8297872340425532,0.9148936170212766,0.7872340425531915,0.9148936170212766,0.8085106382978723,0.8723404255319149,0.0,0.8723404255319149],
   'train_acc':[0.9074074074074074,1.0,0.9351851851851852,1.0,0.9537037037037037,1.0,1.0,1.0]}
df=pd.DataFrame(data=a,index=['Logistic','Decision tree','k-neighbour','random forest','Adaboost','Gradientboost','XGboost','SVC'])

# %%
df.plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
model2.predict([[1,28,5,5.9,4,30,2,11,85,3000,1]])
# Out:
# array([8], dtype=int64)

# %%
# Gender	Age	Occupation	          Sleep Duration	Quality of Sleep	Physical Activity Level	Stress Level BMI Category	Blood Pressure	Heart Rate	Daily Steps	Sleep Disorder
# Male	28	Sales Representative	5.9	                4	                   30	                  8	           Obese	       140/90	       85	    3000   Sleep Apnea

# %%
Gender=input("enter the gender:")
Gender=ob1.transform([Gender])
Occupation=input("enter the Occupation:")
Occupation=ob2.transform([Occupation])
BMI_Category=input("enter the BMI Category:")
BMI_Category=ob3.transform([BMI_Category])
Blood_Pressure=input("enter the Blood_Pressure:")
Blood_Pressure=ob4.transform([Blood_Pressure])
Sleep_Disorder=input("enter the Sleep Disorder:")
Sleep_Disorder=ob5.transform([Sleep_Disorder])
Age=input("enter the age:")
Sleep_Duration=float(input("enter the Sleep_Duration:"))
Quality_of_Sleep=input("enter the Quality_of_Sleep:")
Physical_Activity_Level=input("enter the Physical_Activity_Level:")
Heart_Rate=input("enter the Heart Rate:")
Daily_Steps=input("enter the Daily Steps")
print(model2.predict([[Gender[0],Age,Occupation[0],Sleep_Duration,Quality_of_Sleep,Physical_Activity_Level,BMI_Category[0],Blood_Pressure[0],Heart_Rate,Daily_Steps,Sleep_Disorder[0]]]))
# Out:
# enter the gender: Male
# enter the Occupation: Sales Representative
# enter the BMI Category: Obese
# enter the Blood_Pressure: 140/90
# enter the Sleep Disorder: Sleep Apnea
# enter the age: 28
# enter the Sleep_Duration: 5.9
# enter the Quality_of_Sleep: 4
# enter the Physical_Activity_Level: 30
# enter the Heart Rate: 85
# enter the Daily Steps 3000
# [8]

# %%
# pip install gradio

# %%
# import gradio as gr

# %%
# from sklearn.metrics import accuracy_score

# %%
# Train models
# models = {
#     "Decision tree": DecisionTreeClassifier(),
#     "Random Forest": RandomForestClassifier(n_estimators=100),
#     "GradientBoostingClassifier": GradientBoostingClassifier(n_estimators=250,random_state=1)
# }
# trained_models = {}
# for name, model in models.items():
#     model.fit(xtrain, ytrain)
#     y_pred = model.predict(xtest)
#     acc = accuracy_score(ytest, y_pred)
#     trained_models[name] = model
#     print(f"{name} Accuracy: {acc:.2f}")

# %%
# Define Gradio function
# def predict(model_name, *features):
#     model = trained_models[model_name]
#     input_data = np.array([features])
#     input_scaled = scaler.transform(input_data)
#     prediction = model.predict(input_scaled)[0]
#     return "low stress" if prediction == 1 else "high stress"

# # Create Gradio UI
# with gr.Blocks() as demo:
#     gr.Markdown("# Stress level Prediction Model")
#     model_name = gr.Dropdown(choices=list(trained_models.keys()), label="Choose Model")
#     inputs = [gr.Number(label=col) for col in x.columns]
#     output = gr.Textbox(label="Stress level prediction")
#     submit = gr.Button("Predict")
#     submit.click(predict, inputs=[model_name] + inputs, outputs=output)

# demo.launch()

# %%
# 1,28,5,5.9,4,30,2,11,85,3000,1
